# %% [markdown]
# # Read Csv

# %%
import pandas as pd
csv_1=pd.read_csv("C:\\Users\\Shristi\\OneDrive\\Desktop\\jupyter projects\\Python Pandas\\Downloaded Files\\industry.csv")
csv_1
# Out:
#                          Industry
# 0              Accounting/Finance
# 1    Advertising/Public Relations
# 2              Aerospace/Aviation
# 3   Arts/Entertainment/Publishing
# 4                      Automotive
# 5                Banking/Mortgage
# 6            Business Development
# 7            Business Opportunity
# 8         Clerical/Administrative
# 9         Construction/Facilities
# 10                 Consumer Goods
# 11               Customer Service
# 12             Education/Training
# 13               Energy/Utilities
# 14                    Engineering
# 15            Government/Military
# 16                          Green
# 17                     Healthcare
# 18             Hospitality/Travel
# 19                Human Resources
# 20       Installation/Maintenance
# 21                      Insurance
# 22                       Internet
# 23                Job Search Aids
# 24       Law Enforcement/Security
# 25                          Legal
# ...

# %%
csv_1=pd.read_csv("C:\\Users\\Shristi\\OneDrive\\Desktop\\jupyter projects\\Python Pandas\\Downloaded Files\\industry.csv",nrows=1)
csv_1
# Out:
#              Industry
# 0  Accounting/Finance

# %%
csv_2=pd.read_csv("C:\\Users\\Shristi\\OneDrive\\Desktop\\jupyter projects\\Python Pandas\\Downloaded Files\\customers-100.csv")
csv_2
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
csv_2=pd.read_csv("C:\\Users\\Shristi\\OneDrive\\Desktop\\jupyter projects\\Python Pandas\\Downloaded Files\\customers-100.csv",usecols=["Index","Customer Id"])
csv_2
# Out:
#     Index      Customer Id
# 0       1  DD37Cf93aecA6Dc
# 1       2  1Ef7b82A4CAAD10
# 2       3  6F94879bDAfE5a6
# 3       4  5Cef8BFA16c5e3c
# 4       5  053d585Ab6b3159
# ..    ...              ...
# 95     96  cb8E23e48d22Eae
# 96     97  CeD220bdAaCfaDf
# 97     98  28CDbC0dFe4b1Db
# 98     99  c23d1D9EE8DEB0A
# 99    100  2354a0E336A91A1
#
# [100 rows x 2 columns]

# %%
csv_2=pd.read_csv("C:\\Users\\Shristi\\OneDrive\\Desktop\\jupyter projects\\Python Pandas\\Downloaded Files\\customers-100.csv",usecols=[1,5,6])
csv_2
# Out:
#         Customer Id               City                     Country
# 0   DD37Cf93aecA6Dc       East Leonard                       Chile
# 1   1Ef7b82A4CAAD10  East Jimmychester                    Djibouti
# 2   6F94879bDAfE5a6      Isabelborough         Antigua and Barbuda
# 3   5Cef8BFA16c5e3c         Bensonview          Dominican Republic
# 4   053d585Ab6b3159     West Priscilla  Slovakia (Slovak Republic)
# ..              ...                ...                         ...
# 95  cb8E23e48d22Eae       East Richard                      Guyana
# 96  CeD220bdAaCfaDf       New Bradview                   Sri Lanka
# 97  28CDbC0dFe4b1Db         Ortegaland             Solomon Islands
# 98  c23d1D9EE8DEB0A    Lake Elijahview                       Aruba
# 99  2354a0E336A91A1          Judymouth                    Honduras
#
# [100 rows x 3 columns]

# %%
import pandas as pd
csv_3=pd.read_csv("C:\\Users\\Shristi\\OneDrive\\Desktop\\jupyter projects\\Python Pandas\\Downloaded Files\\industry.csv",skiprows=[1,2,4,6,8,10])
csv_3
# Out:
#                     Industry
# 0         Aerospace/Aviation
# 1                 Automotive
# 2       Business Development
# 3    Clerical/Administrative
# 4             Consumer Goods
# 5           Customer Service
# 6         Education/Training
# 7           Energy/Utilities
# 8                Engineering
# 9        Government/Military
# 10                     Green
# 11                Healthcare
# 12        Hospitality/Travel
# 13           Human Resources
# 14  Installation/Maintenance
# 15                 Insurance
# 16                  Internet
# 17           Job Search Aids
# 18  Law Enforcement/Security
# 19                     Legal
# 20      Management/Executive
# 21  Manufacturing/Operations
# 22                 Marketing
# 23      Non-Profit/Volunteer
# 24    Pharmaceutical/Biotech
# 25     Professional Services
# 26        QA/Quality Control
# 27               Real Estate
# 28   Restaurant/Food Service
# 29                    Retail
# 30                     Sales
# ...

# %%
csv_4=pd.read_csv("C:\\Users\\Shristi\\OneDrive\\Desktop\\jupyter projects\\Python Pandas\\Downloaded Files\\customers-100.csv",index_col="Customer Id")
csv_4
# Out:
#                  Index First Name Last Name                          Company  \
# Customer Id
# DD37Cf93aecA6Dc      1     Sheryl    Baxter                  Rasmussen Group
# 1Ef7b82A4CAAD10      2    Preston    Lozano                      Vega-Gentry
# 6F94879bDAfE5a6      3        Roy     Berry                    Murillo-Perry
# 5Cef8BFA16c5e3c      4      Linda     Olsen  Dominguez, Mcmillan and Donovan
# 053d585Ab6b3159      5     Joanna    Bender         Martin, Lang and Andrade
# ...                ...        ...       ...                              ...
# cb8E23e48d22Eae     96       Karl     Greer                        Carey LLC
# CeD220bdAaCfaDf     97       Lynn  Atkinson            Ware, Burns and Oneal
# 28CDbC0dFe4b1Db     98       Fred    Guerra                    Schmitt-Jones
# c23d1D9EE8DEB0A     99     Yvonne    Farmer               Fitzgerald-Harrell
# 2354a0E336A91A1    100   Clarence    Haynes               Le, Nash and Cross
#
# ...
