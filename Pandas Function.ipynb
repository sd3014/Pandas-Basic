# %% [markdown]
# # Pandas Function

# %%
import pandas as pd
var=pd.read_csv("C:\\Users\\Shristi\\OneDrive\\Desktop\\jupyter projects\\Python Pandas\\Downloaded Files\\organizations-100.csv")
var
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 3              https://becker.com/                 Turkmenistan
# ...

# %%
var.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
var.columns
# Out:
# Index(['Index', 'Organization Id', 'Name', 'Website', 'Country', 'Description',
#        'Founded', 'Industry', 'Number of employees'],
#       dtype='object')

# %%
var.head()
# Out:
#    Index  Organization Id                     Name  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers
# 4      5  9eE8A6a4Eb96C24              Mayer Group
#
#                           Website           Country  \
# 0              https://price.net/  Papua New Guinea
# 1  http://www.hall-buchanan.info/           Finland
# 2       http://sullivan-reed.com/             China
# 3             https://becker.com/      Turkmenistan
# 4          http://www.brewer.com/         Mauritius
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase     1990
# 1             User-centric system-worthy leverage     2015
# 2                  Switchable scalable moratorium     1971
# 3  De-engineered systemic artificial intelligence     2004
# ...

# %%
var.tail()
# Out:
#     Index  Organization Id               Name                  Website  \
# 95     96  0a0bfFbBbB8eC7c       Holmes Group    https://mcdowell.org/
# 96     97  BA6Cd9Dae2Efd62           Good Ltd        http://duffy.com/
# 97     98  E7df80C60Abd7f9  Clements-Espinoza  http://www.flowers.net/
# 98     99  AFc285dbE2fEd24         Mendez Inc   https://www.burke.net/
# 99    100  e9eB5A60Cef8354     Watkins-Kaiser  http://www.herring.com/
#
#                         Country                              Description  \
# 95                     Ethiopia   Right-sized zero tolerance focus group
# 96                     Anguilla  Reverse-engineered composite moratorium
# 97  Falkland Islands (Malvinas)                  Progressive modular hub
# 98              Kyrgyz Republic          User-friendly exuding migration
# 99                         Togo            Synergistic background access
#
#     Founded              Industry  Number of employees
# ...

# %%
var.head(2)
# Out:
#    Index  Organization Id                     Name  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
#
#                           Website           Country  \
# 0              https://price.net/  Papua New Guinea
# 1  http://www.hall-buchanan.info/           Finland
#
#                            Description  Founded                     Industry  \
# 0  Horizontal empowering knowledgebase     1990                     Plastics
# 1  User-centric system-worthy leverage     2015  Glass / Ceramics / Concrete
#
#    Number of employees
# 0                 3498
# 1                 4952

# %%
var.index.array
# Out:
# <NumpyExtensionArray>
# [ np.int64(0),  np.int64(1),  np.int64(2),  np.int64(3),  np.int64(4),
#   np.int64(5),  np.int64(6),  np.int64(7),  np.int64(8),  np.int64(9),
#  np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14),
#  np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19),
#  np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24),
#  np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29),
#  np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(34),
#  np.int64(35), np.int64(36), np.int64(37), np.int64(38), np.int64(39),
#  np.int64(40), np.int64(41), np.int64(42), np.int64(43), np.int64(44),
#  np.int64(45), np.int64(46), np.int64(47), np.int64(48), np.int64(49),
#  np.int64(50), np.int64(51), np.int64(52), np.int64(53), np.int64(54),
#  np.int64(55), np.int64(56), np.int64(57), np.int64(58), np.int64(59),
#  np.int64(60), np.int64(61), np.int64(62), np.int64(63), np.int64(64),
# ...

# %%
var.to_numpy()
# Out:
# array([[1, 'FAB0d41d5b5d22c', 'Ferrell LLC', 'https://price.net/',
#         'Papua New Guinea', 'Horizontal empowering knowledgebase', 1990,
#         'Plastics', 3498],
#        [2, '6A7EdDEA9FaDC52', 'Mckinney, Riley and Day',
#         'http://www.hall-buchanan.info/', 'Finland',
#         'User-centric system-worthy leverage', 2015,
#         'Glass / Ceramics / Concrete', 4952],
#        [3, '0bFED1ADAE4bcC1', 'Hester Ltd', 'http://sullivan-reed.com/',
#         'China', 'Switchable scalable moratorium', 1971, 'Public Safety',
#         5287],
#        [4, '2bFC1Be8a4ce42f', 'Holder-Sellers', 'https://becker.com/',
#         'Turkmenistan', 'De-engineered systemic artificial intelligence',
#         2004, 'Automotive', 921],
#        [5, '9eE8A6a4Eb96C24', 'Mayer Group', 'http://www.brewer.com/',
#         'Mauritius', 'Synchronized needs-based challenge', 1991,
#         'Transportation', 7870],
#        [6, 'cC757116fe1C085', 'Henry-Thompson', 'http://morse.net/',
# ...

# %%
import numpy as np
var1=np.asarray(var)
var1
# Out:
# array([[1, 'FAB0d41d5b5d22c', 'Ferrell LLC', 'https://price.net/',
#         'Papua New Guinea', 'Horizontal empowering knowledgebase', 1990,
#         'Plastics', 3498],
#        [2, '6A7EdDEA9FaDC52', 'Mckinney, Riley and Day',
#         'http://www.hall-buchanan.info/', 'Finland',
#         'User-centric system-worthy leverage', 2015,
#         'Glass / Ceramics / Concrete', 4952],
#        [3, '0bFED1ADAE4bcC1', 'Hester Ltd', 'http://sullivan-reed.com/',
#         'China', 'Switchable scalable moratorium', 1971, 'Public Safety',
#         5287],
#        [4, '2bFC1Be8a4ce42f', 'Holder-Sellers', 'https://becker.com/',
#         'Turkmenistan', 'De-engineered systemic artificial intelligence',
#         2004, 'Automotive', 921],
#        [5, '9eE8A6a4Eb96C24', 'Mayer Group', 'http://www.brewer.com/',
#         'Mauritius', 'Synchronized needs-based challenge', 1991,
#         'Transportation', 7870],
#        [6, 'cC757116fe1C085', 'Henry-Thompson', 'http://morse.net/',
# ...

# %%
var2=var.sort_index(axis=0,ascending=False)
var2
# Out:
#     Index  Organization Id                     Name  \
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# ..    ...              ...                      ...
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
#
#                            Website                      Country  \
# 99         http://www.herring.com/                         Togo
# 98          https://www.burke.net/              Kyrgyz Republic
# 97         http://www.flowers.net/  Falkland Islands (Malvinas)
# 96               http://duffy.com/                     Anguilla
# ...

# %%
var["Name"][0]="Shristi Dey"
var
# Out:
# C:\Users\Shristi\AppData\Local\Temp\ipykernel_15416\2642100303.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   var["Name"][0]="Shristi Dey"
# ...

# %%
var.loc[0,"Name"]="Shristi Dey"
var
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Shristi Dey
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 3              https://becker.com/                 Turkmenistan
# ...

# %%
var.loc[[2,3],["Name","Country"]]
# Out:
#              Name       Country
# 2      Hester Ltd         China
# 3  Holder-Sellers  Turkmenistan

# %%
var.loc[:,["Name","Country"]]
# Out:
#                        Name                      Country
# 0               Shristi Dey             Papua New Guinea
# 1   Mckinney, Riley and Day                      Finland
# 2                Hester Ltd                        China
# 3            Holder-Sellers                 Turkmenistan
# 4               Mayer Group                    Mauritius
# ..                      ...                          ...
# 95             Holmes Group                     Ethiopia
# 96                 Good Ltd                     Anguilla
# 97        Clements-Espinoza  Falkland Islands (Malvinas)
# 98               Mendez Inc              Kyrgyz Republic
# 99           Watkins-Kaiser                         Togo
#
# [100 rows x 2 columns]

# %%
var.loc[[2,3],:]
# Out:
#    Index  Organization Id            Name                    Website  \
# 2      3  0bFED1ADAE4bcC1      Hester Ltd  http://sullivan-reed.com/
# 3      4  2bFC1Be8a4ce42f  Holder-Sellers        https://becker.com/
#
#         Country                                     Description  Founded  \
# 2         China                  Switchable scalable moratorium     1971
# 3  Turkmenistan  De-engineered systemic artificial intelligence     2004
#
#         Industry  Number of employees
# 2  Public Safety                 5287
# 3     Automotive                  921

# %%
var.iloc[2,3]
# Out:
# 'http://sullivan-reed.com/'

# %%
var.drop("Website",axis=1)
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Shristi Dey
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                         Country  \
# 0              Papua New Guinea
# 1                       Finland
# 2                         China
# 3                  Turkmenistan
# 4                     Mauritius
# ..                          ...
# 95                     Ethiopia
# 96                     Anguilla
# 97  Falkland Islands (Malvinas)
# ...
